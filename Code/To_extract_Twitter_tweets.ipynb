# %%
#!pip install tweepy
import tweepy,json
# oauth_token="NPcudxy0yU5T3tBzho7iCotZ3cnetKwcTIRlX0iwRl0"

# oauth_token_secret="veNRnAWe6inFuo8o2u8SLLZLjolYDmDP7SzL0YfYI"
# oauth_consumer_key="OqEqJeafRSF11jBMStrZz"
access_token=""
access_token_secret=""
consumer_key=""
consumer_secret=""

# %%
text_query = '2020 US Election'
count = 150
try:
 # Creation of query method using parameters
 tweets = tweepy.Cursor(api.search,q=text_query).items(count)
 
 # Pulling information from tweets iterable object
 tweets_list = [[tweet.created_at, tweet.id, tweet.text] for tweet in tweets]
 
 # Creation of dataframe from tweets list
 # Add or remove columns as you remove tweet information
 tweets_df = pd.DataFrame(tweets_list)
 
except BaseException as e:
    print('failed on_status,',str(e))
    time.sleep(3)

# %%
import tweepy,json

# %%
consumer_key="HdOI177rKuZrD1k6MGACqKbD6"
consumer_secret="hgVsDcRNV7hwheoBbVhYymvzBMTPoNwvRoqydmRWzlKcfl64lJ"
access_token="1359235244524785669-oDvB2pv5wDHAXZpUllJhbya3PUAbCB"
access_token_secret="ewU7Cg2V6ava1LTkTo5kYVb2T0zOJ2fhuJvbJF2MNXZMo"

# %%
auth= tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)

# %%
tweet_list=[]
class MyStreamListener(tweepy.StreamListener):
    def __init__(self,api=None):
        super(MyStreamListener,self).__init__()
        self.num_tweets=0
        self.file=open("tweet.txt","w")
    def on_status(self,status):
        tweet=status._json
        self.file.write(json.dumps(tweet)+ '\n')
        tweet_list.append(status)
        self.num_tweets+=1
        if self.num_tweets<100000:
            return True
        else:
            return False
        self.file.close()

# %%
#create streaming object and authenticate


#'Covid19', 'CovidAtWork', 'Covid-19', 'CoronaVirus', 'CoronaVirus19', 'CovidVaccine', 'VaccineWork', 'VaccinesSaveLife', 'Vaccine Strategy','VaccineStrategy', 'Covid'

l = MyStreamListener()
stream =tweepy.Stream(auth,l)

stream.filter(track=['Covid19', 'CovidAtWork', 'Covid-19', 'CoronaVirus', 'CoronaVirus19', 'CovidatWork', 'unemployment', 'career', 'workingpoor','poverty', 'Covid'])
stream.filter(languages=["en"])

# %%
# print(len(tweets_data))

# %%
# import pandas as pd
# df = pd.DataFrame.from_dict(tweets_data, orient='columns')

# %%
df.to_csv('Covid_Tweets.csv')

# %%
df['text']
# Out:
# 0      RT @planwac: Hoy, por segunda vez en menos de ...
# 1      RT @httpquack: this thread has a lot more inci...
# 2      RT @SofiaMirandaCs: Los clubes deportivos son ...
# 3      RT @candies2639: 40 Percent of U.S. COVID Deat...
# 4      RT @ashishkjha: Texas ranks #40 in the nation ...
#                              ...
# 995    RT @yeshe_paljor: First spread the disease and...
# 996    RT @azfrankie: mit mehr als 800.000 Abonnenten...
# 997    Peds take on this +++ study. Toci had absolute...
# 998    RT @OMGno2trump: It makes sense the Senate GOP...
# 999    RT @forzacimbomtr: SKANDAL!\n\nCovid 19 yasakl...
# Name: text, Length: 1000, dtype: object

# %%
tweets_data_path='tweet.txt'
tweets_data=[]
tweets_file=open(tweets_data_path,"r")
#read in tweets and store on list
for line in tweets_file:
    tweet=json.loads(line)
    tweets_data.append(tweet)
tweets_file.close()
print(tweets_data[0])
# Out:
# {'created_at': 'Fri Mar 26 16:22:19 +0000 2021', 'id': 1375483261326135303, 'id_str': '1375483261326135303', 'text': 'RT @lesleyanngreen: 50 NOT OUT!!! https://t.co/KibAzagQ0k via @lesleyanngreen @MaryEGater first published Feb 2019 even more relevant now w…', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 232617366, 'id_str': '232617366', 'name': 'Cheshire Girl', 'screen_name': 'lesleyanngreen', 'location': 'Cheshire. UK 🇬🇧 ', 'url': 'http://Www.psychologytoday.com/profile/412570', 'description': 'HEALTH is WEALTH\nPsychotherapist, writer, health advocate for over 50’s women \nBSc Psych (hons), MSc Clinical Science\n\nBlog -:  https://t.co/Y3M4l0AlfX', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 2734, 'friends_co
# ...

# %%
# len(tweets_data)
df = pd.DataFrame.from_dict(tweets_data, orient='columns')

# %%
df.to_csv('covid_data_on_26_03_2021.csv')

# %%
df1=pd.read_csv('C:\\Users\\muppa\\covid_data_on_20_03_2021.csv')
# Out:
# C:\Users\muppa\AppData\Roaming\Python\Python38\site-packages\IPython\core\interactiveshell.py:3155: DtypeWarning: Columns (13,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df1.shape
# Out:
# (19999, 38)

# %%
df1.head()
# Out:
#    Unnamed: 0                      created_at                   id  \
# 0           0  Sat Mar 20 14:24:20 +0000 2021  1373279244395016192
# 1           1  Sat Mar 20 14:24:20 +0000 2021  1373279244298682368
# 2           2  Sat Mar 20 14:24:20 +0000 2021  1373279244269289473
# 3           3  Sat Mar 20 14:24:20 +0000 2021  1373279244403404801
# 4           4  Sat Mar 20 14:24:20 +0000 2021  1373279244415946756
#
#                 id_str                                               text  \
# 0  1373279244395016192  RT @picardonhealth: Scientists say they have i...
# 1  1373279244298682368  RT @Alejand26557780: Buenos Dias\n#FrenaElCont...
# 2  1373279244269289473  @teamleafs94 @CP24 How about the restaurant in...
# 3  1373279244403404801  RT @atomaraullo: As we reel from a record numb...
# 4  1373279244415946756  RT @ByMikeBaker: My goodness. At the men's bas...
#
#                                               source  truncated  \
# ...

# %%
df1.drop(['Unnamed: 0'],axis=1, inplace=True)

# %%
df1.head()
# Out:
#                        created_at                   id               id_str  \
# 0  Sat Mar 20 14:24:20 +0000 2021  1373279244395016192  1373279244395016192
# 1  Sat Mar 20 14:24:20 +0000 2021  1373279244298682368  1373279244298682368
# 2  Sat Mar 20 14:24:20 +0000 2021  1373279244269289473  1373279244269289473
# 3  Sat Mar 20 14:24:20 +0000 2021  1373279244403404801  1373279244403404801
# 4  Sat Mar 20 14:24:20 +0000 2021  1373279244415946756  1373279244415946756
#
#                                                 text  \
# 0  RT @picardonhealth: Scientists say they have i...
# 1  RT @Alejand26557780: Buenos Dias\n#FrenaElCont...
# 2  @teamleafs94 @CP24 How about the restaurant in...
# 3  RT @atomaraullo: As we reel from a record numb...
# 4  RT @ByMikeBaker: My goodness. At the men's bas...
#
#                                               source  truncated  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...      False
# ...

# %%
df.head()
# Out:
#                        created_at                   id               id_str  \
# 0  Fri Mar 26 16:22:19 +0000 2021  1375483261326135303  1375483261326135303
# 1  Fri Mar 26 16:22:19 +0000 2021  1375483261334478851  1375483261334478851
# 2  Fri Mar 26 16:22:19 +0000 2021  1375483261128966147  1375483261128966147
# 3  Fri Mar 26 16:22:19 +0000 2021  1375483261355491336  1375483261355491336
# 4  Fri Mar 26 16:22:19 +0000 2021  1375483261510504448  1375483261510504448
#
#                                                 text  \
# 0  RT @lesleyanngreen: 50 NOT OUT!!! https://t.co...
# 1  @m_plaszczyk @kowalski_cezary Poza tym rzuć ok...
# 2  RT @glennkirschner2: LAST CALL to sign the let...
# 3  RT @SanjayLokmat: नाशिक महापालिकेच्या वैद्यकीय...
# 4  RT @butantanoficial: Um dia histórico. O Butan...
#
#                                               source  truncated  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...      False
# ...

# %%
new_df=pd.concat([df,df1],axis=0)

# %%
new_df.shape
# Out:
# (119999, 37)

# %%
# new_df['source'].dropna().apply(lambda x: x.split('>')[0].split('<')).unique()
# new_df['source'].dropna().apply(lambda x: re.search(r'>.(.*?)<', x).group(0).replace('>','').replace('<','')).unique()
# new_df['source'].dropna().apply(lambda x: re.search(r'>.(.*?)<', x).group(0).replace('>','').replace('<','')).unique()
# re.search(r'>.(.*?)<', t).group(0).replace('>','').replace('<','')

# %%
new_df['source'].
# Out:
# 0         <a href="https://mobile.twitter.com" rel="nofo...
# 1         <a href="http://twitter.com/download/android" ...
# 2         <a href="http://twitter.com/download/android" ...
# 3         <a href="https://twitter.com/nashik_feed" rel=...
# 4         <a href="https://mobile.twitter.com" rel="nofo...
#                                 ...
# 119994    <a href="https://mobile.twitter.com" rel="nofo...
# 119995    <a href="http://twitter.com/download/android" ...
# 119996    <a href="https://mobile.twitter.com" rel="nofo...
# 119997    <a href="http://twitter.com/download/iphone" r...
# 119998    <a href="http://twitter.com/download/android" ...
# Name: source, Length: 119967, dtype: object

# %%
t='<a href="https://twitter.com/witboxgo?lang=es" rel="nofollow">pythonTwitterTest Nik</a>'

# %%
import re
# re.search(r'values\s=\s<\s*(.+)\s*>\s', t)
re.search(r'>.(.*?)<', t).group(0).replace('>','').replace('<','')
# Out:
# 'pythonTwitterTest Nik'

# %%
new_df.index=range(0,new_df.shape[0])

# %%
new_df['source'][0].split('>')[1].split('<')[0]
# Out:
# 'Twitter Web App'

# %%
new_df.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'text', 'source', 'truncated',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place',
#        'contributors', 'retweeted_status', 'is_quote_status', 'quote_count',
#        'reply_count', 'retweet_count', 'favorite_count', 'entities',
#        'favorited', 'retweeted', 'possibly_sensitive', 'filter_level', 'lang',
#        'timestamp_ms', 'display_text_range', 'extended_tweet',
#        'quoted_status_id', 'quoted_status_id_str', 'quoted_status',
#        'quoted_status_permalink', 'extended_entities',
#        'withheld_in_countries'],
#       dtype='object')

# %%
location=[]
for i in range(0,df.shape[0]):
    try:
        location.append(df['user'][i]['location'])
    except:
        print(i)
# Out:
# 100000
# 100001
# 100002
# 100003
# 100004
# 100005
# 100006
# 100007
# 100008
# 100009
# 100010
# 100011
# 100012
# 100013
# 100014
# 100015
# 100016
# 100017
# 100018
# 100019
# 100020
# 100021
# 100022
# 100023
# 100024
# 100025
# 100026
# 100027
# 100028
# 100029
# 100030
# 100031
# 100032
# 100033
# 100034
# 100035
# 100036
# 100037
# 100038
# 100039
# 100040
# 100041
# 100042
# 100043
# 100044
# 100045
# 100046
# 100047
# 100048
# 100049
# 100050
# 100051
# 100052
# 100053
# 100054
# 100055
# 100056
# 100057
# 100058
# 100059
# 100060
# 100061
# 100062
# 100063
# 100064
# 100065
# 100066
# 100067
# 100068
# 100069
# 100070
# 100071
# 100072
# 100073
# 100074
# 100075
# 100076
# 100077
# 100078
# 100079
# 100080
# 100081
# 100082
# 100083
# 100084
# 100085
# 100086
# 100087
# 100088
# 100089
# 100090
# 100091
# 100092
# 100093
# 100094
# 100095
# 100096
# 100097
# 100098
# 100099
# 100100
# 100101
# 100102
# 100103
# 100104
# 100105
# 100106
# 100107
# 100108
# 100109
# 100110
# ...

# %%
df['location']=df['user'].apply(lambda x: x['location'])

# %%
t=df['location'].value_counts(ascending=False)[:10]

# %%
t
# Out:
# Venezuela                 767
# United States             517
# Brasil                    486
# São Paulo, Brasil         467
# France                    407
# London, England           401
# Rio de Janeiro, Brasil    374
# Paris, France             333
# Canada                    318
# India                     312
# Name: location, dtype: int64

# %%
t.values
# Out:
# array([767, 517, 486, 467, 407, 401, 374, 333, 318, 312], dtype=int64)

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,3,3])
# langs = ['C', 'C++', 'Java', 'Python', 'PHP']
# students = [23,17,35,29,12]
ax.bar(t.index,t.values)
plt.show()

# %%
new_df['location']=new_df['user'].apply(lambda x: x['location'])
